# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_report = pd.read_csv("/home/vincey/Desktop/data anaylsis/WHR2023.csv")
df_report.tail()
# Out:
#          Country name  Ladder score  Standard error of ladder score  \
# 132  Congo (Kinshasa)         3.207                           0.095
# 133          Zimbabwe         3.204                           0.061
# 134      Sierra Leone         3.138                           0.082
# 135           Lebanon         2.392                           0.044
# 136       Afghanistan         1.859                           0.033
#
#      upperwhisker  lowerwhisker  Logged GDP per capita  Social support  \
# 132         3.394         3.020                  7.007           0.652
# 133         3.323         3.084                  7.641           0.690
# 134         3.299         2.976                  7.394           0.555
# 135         2.479         2.305                  9.478           0.530
# 136         1.923         1.795                  7.324           0.341
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# ...

# %%
sns.set_style('darkgrid')
plt.rcParams['font.size'] = 15
plt.rcParams['figure.figsize'] = (10,7)
plt.rcParams['figure.facecolor'] ='#ffe5b4'

# %%
df_report_columns = ['Country name','Ladder score','Logged GDP per capita','Social support','Healthy life expectancy','Freedom to make life choices','Generosity','Perceptions of corruption']

# %%
df_report = df_report[df_report_columns].copy()

# %%
happy_df = df_report.rename(columns={'Country name':'country','Ladder score':'ladder_score','Logged GDP per capita':'logged_GDP_per_capita','Social support':'social_support','Generosity':'generosity','Healthy life expectancy':'healthy_life_expectancy','Perceptions of corruption':'perceptions_of_corruption','Freedom to make life choices':'freedom_to_make_life_choices'})

# %%
happy_df.head()
# Out:
#        country  ladder_score  logged_GDP_per_capita  social_support  \
# 0      Finland         7.804                 10.792           0.969
# 1      Denmark         7.586                 10.962           0.954
# 2      Iceland         7.530                 10.896           0.983
# 3       Israel         7.473                 10.639           0.943
# 4  Netherlands         7.403                 10.942           0.930
#
#    healthy_life_expectancy  freedom_to_make_life_choices  generosity  \
# 0                   71.150                         0.961      -0.019
# 1                   71.250                         0.934       0.134
# 2                   72.050                         0.936       0.211
# 3                   72.697                         0.809      -0.023
# 4                   71.550                         0.887       0.213
#
#    perceptions_of_corruption
# 0                      0.182
# 1                      0.196
# 2                      0.668
# ...

# %%
happy_df.isnull().sum()
# Out:
# country                         0
# ladder_score                    0
# logged_GDP_per_capita           0
# social_support                  0
# healthy_life_expectancy         1
# freedom_to_make_life_choices    0
# generosity                      0
# perceptions_of_corruption       0
# dtype: int64

# %%
happy_df.count()
# Out:
# country                         137
# ladder_score                    137
# logged_GDP_per_capita           137
# social_support                  137
# healthy_life_expectancy         136
# freedom_to_make_life_choices    137
# generosity                      137
# perceptions_of_corruption       137
# dtype: int64

# %%
# filling the null values with the median vaue of healthy life expectancy
happy_df['healthy_life_expectancy'] = happy_df['healthy_life_expectancy'].fillna(happy_df['healthy_life_expectancy'].median())
happy_df
# Out:
#               country  ladder_score  logged_GDP_per_capita  social_support  \
# 0             Finland         7.804                 10.792           0.969
# 1             Denmark         7.586                 10.962           0.954
# 2             Iceland         7.530                 10.896           0.983
# 3              Israel         7.473                 10.639           0.943
# 4         Netherlands         7.403                 10.942           0.930
# ..                ...           ...                    ...             ...
# 132  Congo (Kinshasa)         3.207                  7.007           0.652
# 133          Zimbabwe         3.204                  7.641           0.690
# 134      Sierra Leone         3.138                  7.394           0.555
# 135           Lebanon         2.392                  9.478           0.530
# 136       Afghanistan         1.859                  7.324           0.341
#
# ...

# %%
happy_df.isnull().sum()
# Out:
# country                         0
# ladder_score                    0
# logged_GDP_per_capita           0
# social_support                  0
# healthy_life_expectancy         0
# freedom_to_make_life_choices    0
# generosity                      0
# perceptions_of_corruption       0
# dtype: int64

# %%
happy_df.count()
# Out:
# country                         137
# ladder_score                    137
# logged_GDP_per_capita           137
# social_support                  137
# healthy_life_expectancy         137
# freedom_to_make_life_choices    137
# generosity                      137
# perceptions_of_corruption       137
# dtype: int64

# %%
# plot btw happiness and Gdp

plt.rcParams['figure.figsize'] = (15,7)
plt.title("Plot between Ladder Score and GDP")
sns.scatterplot(x=happy_df.ladder_score, y=happy_df.logged_GDP_per_capita, hue= happy_df.healthy_life_expectancy, s=200);
# hue= happy_df.healthy_life_expectancy  can be replaced with regional
plt.legend(loc = 'upper left', fontsize ='10')
plt.xlabel('ladder Score')
plt.ylabel('GDP per capita')
# Out:
# Text(0, 0.5, 'GDP per capita')

# %%
gdp_region = happy_df.groupby('healthy_life_expectancy')['logged_GDP_per_capita'].sum()
gdp_region
# Out:
# healthy_life_expectancy
# 51.530     7.116
# 53.125     7.261
# 54.050     7.641
# 54.185     7.880
# 54.712     7.324
#            ...
# 72.900    11.164
# 73.650    10.693
# 73.800    11.571
# 74.349    10.616
# 77.280    10.966
# Name: logged_GDP_per_capita, Length: 126, dtype: float64

# %%
# gdp_region.plot.pie(autopct = '%1.1f%%')
# plt.title('GDP by Life Expectancy')
# plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
# Total countries

total_country = happy_df.groupby()
